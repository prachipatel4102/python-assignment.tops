# %%
#Q1
import requests
url = "https://api.coingecko.com/api/v3/coins/markets"
params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 10,
    "page": 1
}

response = requests.get(url, params=params)

coins = response.json()

print("-" * 75)
print(f"{'Name':15} {'Price($)':12} {'24h Change%':15} {'24h High':12} {'24h Low'}")
print("-" * 75)
for coin in coins:
    print(f"{coin['name']:15} "
          f"{coin['current_price']:<12} "
          f"{coin['price_change_percentage_24h']:<15.2f} "
          f"{coin['high_24h']:<12} "
          f"{coin['low_24h']}")

#Q2

doubt

#Q3
 doubt
