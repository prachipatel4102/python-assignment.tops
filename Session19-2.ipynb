# %%
#Q1
class song:
    def __init__(self,title,artist,duration):
        self.title=title
        self.artist=artist
        self.duration=duration

song1=song("Kesariya","Arijit singh",270)
print("title:",song1.title)
print("artist:",song1.artist)
print("duration",song1.duration)

#Q2
class song:
    def __init__(self,title,artist,duration):
        self.title=title
        self.artist=artist
        self.duration=duration

    def play_preview(self):
        print("playing 30preview of ",self.title,"by",self.artist)

song1=song("apna bana le","Arijit singh",250)
song1.play_preview()

#Q3
class foodorder:
    def __init__(self,restaurent_name,items,total_price):
        self.restaurent_name=restaurent_name
        self.items=items
        self.total_price=total_price

order1=foodorder("dominos",["pizza","garlic bread"],650)
print("restaurent name",order1.restaurent_name)
print("items",order1.items)
print("total_price",order1.total_price)

#Q4
class foodorder:
    def __init__(self,restaurent_name,items,total_price):
        self.restaurent_name=restaurent_name
        self.items=items
        self.total_price=total_price

    def add_item(self,item_name,item_price):
        self.items.append(item_name)
        self.total_price+=item_price

order1=foodorder("dominos",["pizza"],500)
order1.add_item("garlic bread",200)
order1.add_item("coke",60)
print("restaurent:",order1.restaurent_name)
print("items:",order1.items)
print("total price",order1.total_price)

#Q5
class song:
    def __init__(self,title,artist,duration=0):
        self.title=title
        self.artist=artist
        self.duration=duration
song1=song("kesariya","arijit singh",270)
song2=song("apna bana le","Arijt singh")
print(song1.title,"-",song1.duration)
print(song2.title,"-",song2.duration)
# Out:
# title: Kesariya
# artist: Arijit singh
# duration 270
# playing 30preview of  apna bana le by Arijit singh
# restaurent name dominos
# items ['pizza', 'garlic bread']
# total_price 650
# restaurent: dominos
# items: ['pizza', 'garlic bread', 'coke']
# total price 760
# kesariya - 270
# apna bana le - 0
