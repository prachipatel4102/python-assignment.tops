# %%
#Q1
apps=["zomato","swiggy","toing","dominos","zepto"]
app_iterator=iter(apps)
print(next(app_iterator))
print(next(app_iterator))
print(next(app_iterator))
print(next(app_iterator))
print(next(app_iterator))

#Q2
def generator_playlist(songs):
    for song in songs:
        yield song

playlist=["Bairan","apna bana le","Dooron","i wanna be yours"]
for song in generator_playlist(playlist):
    print(song)

#Q3
cart_list=["Pizza","burger","coke","garlic bread"]
for index,name in enumerate(cart_list,start=1):
    print("item",index,":",name)

#Q4
teams=["Mumbai indinas","gujarat titans","royal chaalengers bengluru",]
points=[20,18,15]
for team,point in zip(teams,points):
    print("team",team,",points:",point)

#Q5
def order_id_generator():
    order_id=1001
    while True:
        yield order_id
        order_id+=1

orders=order_id_generator()
print(next(orders))
print(next(orders))
print(next(orders))
print(next(orders))
print(next(orders))
# Out:
# zomato
# swiggy
# toing
# dominos
# zepto
# Bairan
# apna bana le
# Dooron
# i wanna be yours
# item 1 : Pizza
# item 2 : burger
# item 3 : coke
# item 4 : garlic bread
# team Mumbai indinas ,points: 20
# team gujarat titans ,points: 18
# team royal chaalengers bengluru ,points: 15
# 1001
# 1002
# 1003
# 1004
# 1005
