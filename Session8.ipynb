# %%
#Q1
# apps=["zomato","swiggy","toing","bigbasket","zepto"]
# for app in apps:
#     print(app)

#Q2
steps=[3000,4500,5000,10000,12000,15000,20000]
week=["monday","tuesday","wednesday","thursday","friday","saturday","sunday"]
i=0
while i <len(steps):
    if steps[i]>10000:
        print("first day with more than 10000 step",week[i])
        break
    i +=1

#Q3
def print_long_teams(teams):
    for team in teams:
        if len(team) <=6:
            continue
        print(team)

ipl_teams=[
    "MI","CSK","KKR","RCB",
    "gujarat titans","sunriser hyderabad","lucknow super giants","punjab kings"
]
print_long_teams(ipl_teams)

#Q4
duration=[210,340,150,200,300]
for position,duration in enumerate(duration,start=1):
    print(f"song {position}:{duration}seconds") 

#Q5
prices=[450,700.0,600,500,300,400]
total=0
for price in prices:
    if price == 0:
        continue
    total+=price
    if total>2000:
        break
print("final total ",total)
# Out:
# first day with more than 10000 step friday
# gujarat titans
# sunriser hyderabad
# lucknow super giants
# punjab kings
# song 1:210seconds
# song 2:340seconds
# song 3:150seconds
# song 4:200seconds
# song 5:300seconds
# final total  2250.0
