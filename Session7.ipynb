# %%
#Q1
listing_time=int(input("enter your spotify listing time in minutes"))
if listing_time>120:
    print("you are a true music fan")
else:
    print("keep listing")

#Q2
order_amount=float(input("Enter your zomato order amount"))
if order_amount > 300:
    print("elgible for free delivery")
else:
    print("deliver charge apply")

#Q3
cart_total=float(input("enter your flipkart cart total"))
if cart_total>2000:
    print("you get a 10% discount")
elif cart_total>1000:
    print("you get a 20% discount")
else:
    print("no discount available")

#Q4
points=int(input("enter your ipl fantsay team points"))
if points>800:
    print("champion")
else:
    if points>=500:
        print("top performer")
    else:
        print("keep trying")
